# %% [markdown]
# # 6.3 Interacting with Web APIs
# * Many websites have public APIs providing data feeds via `JSON` or some other format.
# * There are a number of ways to access these APIs from Python; one easy-to-use method that I recommend is the `requests` package.

# %% [markdown]
# To find the last 30 GitHub issues for pandas on GitHub, we can make a `GET HTTP` request using the add-on `requests` library:

# %%
import pandas as pd
import numpy as np

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %% [markdown]
# The Response object’s `json` method will return a dictionary containing `JSON` parsed into native Python objects:

# %%
data = resp.json()
data[0]['labels']
# Out:
# [{'id': 76811,
#   'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#   'name': 'Bug',
#   'color': 'e10c02',
#   'default': False,
#   'description': None},
#  {'id': 1954720290,
#   'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#   'name': 'Needs Triage',
#   'color': '0052cc',
#   'default': False,
#   'description': 'Issue that has not been reviewed by a pandas team member'}]

# %% [markdown]
# Each element in data is a dictionary containing all of the data found on a GitHub issue page (except for the comments). We can pass data directly to DataFrame and extract fields of interest:

# %%
issues = pd.DataFrame(data, columns=['number', 'title','labels', 'state'])
issues
# Out:
#     number                                              title  \
# 0    35267                                               BUG:
# 1    35266  REGR: setting column with setitem should not m...
# 2    35265  ENH: Add `into` argument for `to_xarray` method?
# 3    35264                                              DOC:
# 4    35261                      Failures with pytest 6.0.0rc1
# 5    35259           ENH: Basis for a StringDtype using Arrow
# 6    35258  [BUG] fixed DateOffset pickle bug when months ...
# 7    35257  Add keep parameter for duplicates values in id...
# 8    35256                             PERF: array_equivalent
# 9    35254                       BUG: df.sum with Int64 dtype
# 10   35252  CI: warning from setuptools (Numpy Dev Build F...
# 11   35251  Inconsistent NA handling for BinGrouper and Gr...
# 12   35249  Performance Regression in frame_methods.Equals...
# 13   35248  BUG: Resampling a Series with a DST to 24 hour...
# 14   35247  PERF: DataFrame.query slow when it contains Pe...
# 15   35246  BUG: AttributeError when doing groupby with as...
# 16   35245                   REF: de-duplicate get_resolution
# 17   35244                          ASV: dt64arr_to_periodarr
# 18   35241  BUG: GroupBy.count() and GroupBy.sum() incorre...
# 19   35240  BUG: concat along the index (axis=0) of two da...
# 20   35238  REGR: concat on index with duplicate labels fails
# 21   35236  TST: added tests for sparse and date range qua...
# 22   35235  CLN/DOC: DataFrame.to_parquet supports file-li...
# 23   35234  TST add test for dtype consistency with pd rep...
# 24   35233  TST: Verify filtering operations on DataFrames...
# 25   35231     BUG: Inconsistent behavior in Index.difference
# 26   35229  Place the calculation of mask prior to the cal...
# 27   35228        COMPAT: Ensure rolling indexers return intp
# 28   35227  BUG: ValueError: Cannot convert non-finite val...
# 29   35226                            REF: Dataframe.__init__
#
#                                                labels state
# 0   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 1   [{'id': 2822098, 'node_id': 'MDU6TGFiZWwyODIyM...  open
# 2   [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 3   [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 4   [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 5                                                  []  open
# 6   [{'id': 76865106, 'node_id': 'MDU6TGFiZWw3Njg2...  open
# 7   [{'id': 35818298, 'node_id': 'MDU6TGFiZWwzNTgx...  open
# 8   [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 9                                                  []  open
# 10  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 11  [{'id': 1741841389, 'node_id': 'MDU6TGFiZWwxNz...  open
# 12  [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 13  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 14  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 15  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 16  [{'id': 127681, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 17  [{'id': 732775912, 'node_id': 'MDU6TGFiZWw3MzI...  open
# 18                                                 []  open
# 19  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 20  [{'id': 77550281, 'node_id': 'MDU6TGFiZWw3NzU1...  open
# 21  [{'id': 57296398, 'node_id': 'MDU6TGFiZWw1NzI5...  open
# 22  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 23  [{'id': 78527356, 'node_id': 'MDU6TGFiZWw3ODUy...  open
# 24  [{'id': 78527356, 'node_id': 'MDU6TGFiZWw3ODUy...  open
# 25  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 26  [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 27  [{'id': 76865106, 'node_id': 'MDU6TGFiZWw3Njg2...  open
# 28  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 29  [{'id': 1465286368, 'node_id': 'MDU6TGFiZWwxND...  open
